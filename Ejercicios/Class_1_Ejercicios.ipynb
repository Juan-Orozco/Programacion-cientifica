# %% [markdown]
# <a href="https://colab.research.google.com/github/Juan-Orozco/Programacion-cientifica/blob/main/Ejercicios/Class_1_Ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicios

# %%
print("Hola Mundo")
# Out:
# Hola Mundo
